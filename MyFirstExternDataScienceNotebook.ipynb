# %% [markdown]
# <a href="https://colab.research.google.com/github/silvia-j-escobar/ExternDataScience/blob/main/MyFirstExternDataScienceNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1️⃣ Print a nice message
print("My name is Silvia and I am the best Data Scientist!")

# 2️⃣ Perform basic math operations
a = 17
b = 9
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)

# 3️⃣ Work with text (strings)
name = "Daniel"
print("Hello, " + name + "!")

# 4️⃣ Store and display a list of numbers
numbers = [4, 17, 9, 29, 14]
print("List of numbers:", numbers)

# 5️⃣ Check data types
print("Type of a:", type(a))
print("Type of name:", type(name))
# Out:
# My name is Silvia and I am the best Data Scientist!
# Addition: 26
# Subtraction: 8
# Multiplication: 153
# Division: 1.8888888888888888
# Hello, Daniel!
# List of numbers: [4, 17, 9, 29, 14]
# Type of a: <class 'int'>
# Type of name: <class 'str'>
